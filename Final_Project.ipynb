# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Berlin_crimes.csv')

# %%
df
# Out:
#       Year       District    Code                                Location  \
# 0     2012          Mitte   10111                          Tiergarten Süd
# 1     2012          Mitte   10112                       Regierungsviertel
# 2     2012          Mitte   10113                          Alexanderplatz
# 3     2012          Mitte   10114                       Brunnenstraße Süd
# 4     2012          Mitte   10221                             Moabit West
# ...    ...            ...     ...                                     ...
# 1195  2019  Reinickendorf  123012  Nord 2 - Waidmannslust/Wittenau/Lübars
# 1196  2019  Reinickendorf  123021               MV 1 - Märkisches Viertel
# 1197  2019  Reinickendorf  123022                 MV 2 - Rollbergsiedlung
# 1198  2019  Reinickendorf  123043      West 3 - Borsigwalde/Freie Scholle
# 1199  2019  Reinickendorf  129900           Bezirk (Rd), nicht zuzuordnen
#
#       Robbery  Street_robbery  Injury  Agg_assault  Threat  Theft  Car  \
# ...

# %% [markdown]
# ### Overview

# %%
#rename Agg_assault for better understanding
berlin = df.rename(columns={'Agg_assault': 'Aggravated_assault'})

# %%
#convert all columns to lower case

berlin.columns = berlin.columns.str.lower()

# %%
#dropping local column because I'm not sure what this means and code becuase its not needed

berlin = berlin.drop('code',axis=1)
berlin= berlin.drop('local',axis=1)

# %%
berlin
# Out:
#       year       district                                location  robbery  \
# 0     2012          Mitte                          Tiergarten Süd       70
# 1     2012          Mitte                       Regierungsviertel       65
# 2     2012          Mitte                          Alexanderplatz      242
# 3     2012          Mitte                       Brunnenstraße Süd       52
# 4     2012          Mitte                             Moabit West      130
# ...    ...            ...                                     ...      ...
# 1195  2019  Reinickendorf  Nord 2 - Waidmannslust/Wittenau/Lübars       34
# 1196  2019  Reinickendorf               MV 1 - Märkisches Viertel       42
# 1197  2019  Reinickendorf                 MV 2 - Rollbergsiedlung        6
# 1198  2019  Reinickendorf      West 3 - Borsigwalde/Freie Scholle        8
# 1199  2019  Reinickendorf           Bezirk (Rd), nicht zuzuordnen        3
#
# ...

# %%
berlin["year"].unique()
# Out:
# array([2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])

# %%
berlin['robbery'].count()
# Out:
# 1200

# %%
#unique number of years
berlin['year'].unique()
# Out:
# array([2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])

# %%
#unique number of district
berlin['district'].unique()
# Out:
# array(['Mitte', 'Friedrichshain-Kreuzberg', 'Pankow',
#        'Charlottenburg-Wilmersdorf', 'Spandau', 'Steglitz-Zehlendorf',
#        'Tempelhof-Schöneberg', 'Neukölln', 'Treptow-Köpenick',
#        'Marzahn-Hellersdorf', 'Lichtenberg', 'Reinickendorf'],
#       dtype=object)

# %%
#unique number of locations
berlin['location'].unique()
# Out:
# array(['Tiergarten Süd', 'Regierungsviertel', 'Alexanderplatz',
#        'Brunnenstraße Süd', 'Moabit West', 'Moabit Ost', 'Osloer Straße',
#        'Brunnenstraße Nord', 'Parkviertel', 'Wedding Zentrum',
#        'Bezirk (Mi), nicht zuzuordnen', 'Südliche Friedrichstadt',
#        'Tempelhofer Vorstadt', 'nördliche Luisenstadt',
#        'südliche Luisenstadt', 'Karl-Marx-Allee-Nord',
#        'Karl-Marx-Allee-Süd', 'Frankfurter Allee Nord',
#        'Frankfurter Allee Süd FK', 'Bezirk (Fh-Kb), nicht zuzuordnen',
#        'Buch', 'Blankenfelde/Niederschönhausen', 'Buchholz', 'Karow',
#        'Blankenburg/Heinersdorf/Märchenland',
#        'Schönholz/Wilhelmsruh/Rosenthal', 'Pankow Zentrum', 'Pankow Süd',
#        'Weißensee', 'Weißensee Ost', 'Prenzlauer Berg Nordwest',
#        'Prenzlauer Berg Nord', 'Helmholtzplatz', 'Prenzlauer Berg Ost',
#        'Prenzlauer Berg Südwest', 'Prenzlauer Berg Süd',
#        'Bezirk (Pk), nicht zuzuordnen', 'Charlottenburg-Nord',
# ...

# %%
#grouping locations by district (why 8)
pd.options.display.max_rows = None #views maximum number of rows
grouped = berlin.groupby(['district','location'])['location'].count()
print(grouped)
# Out:
# district                    location
# Charlottenburg-Wilmersdorf  Barstraße                                    8
#                             Bezirk (Ch-Wi), nicht zuzuordnen             8
#                             Charlottenburg-Nord                          8
#                             Düsseldorfer Straße                          8
#                             Forst Grunewald                              8
#                             Grunewald                                    8
#                             Halensee                                     8
#                             Heerstrasse                                  8
#                             Kantstraße                                   8
#                             Kurfürstendamm                               8
#                             Mierendorffplatz                             8
#                             Neue Kantstraße                              8
# ...

# %%
#count = berlin['location'].str.count('Heerstrasse').sum()
#count

# %%
# grouping districts by locations

grouped = berlin.groupby('district')['location']
value_counts = grouped.value_counts()
print(value_counts)
# Out:
# district                    location
# Charlottenburg-Wilmersdorf  Barstraße                                    8
#                             Bezirk (Ch-Wi), nicht zuzuordnen             8
#                             Charlottenburg-Nord                          8
#                             Düsseldorfer Straße                          8
#                             Forst Grunewald                              8
#                             Grunewald                                    8
#                             Halensee                                     8
#                             Heerstrasse                                  8
#                             Kantstraße                                   8
#                             Kurfürstendamm                               8
#                             Mierendorffplatz                             8
#                             Neue Kantstraße                              8
# ...

# %%
# group the crimes committed by year
grouped_df = berlin.groupby('year').sum()
grouped_df
# Out:
#       robbery  street_robbery  injury  aggravated_assault  threat   theft  \
# year
# 2012     6283            2886   42153               11032   14196  207340
# 2013     6088            3135   41461               10247   14333  220417
# 2014     5583            3228   39190                9515   13733  229955
# 2015     5318            2914   39312                9664   13260  251366
# 2016     5046            2962   41339               10024   13557  251192
# 2017     4165            2324   42283               10608   13452  220220
# 2018     4202            2417   42828               10656   13965  209957
# 2019     4395            2627   43035               10754   14604  200322
#
#        car  from_car   bike  burglary  fire  arson  damage  graffiti  drugs  \
# year
# 2012  5732     30503  25836     12285  2514    904   48582     11070  11687
# 2013  6628     35652  26389     11563  2561    972   43176      9573  12746
# ...

# %%
#ax = grouped_df.plot(x="year", y=["robbery","street_robbery", "theft"], kind="bar", rot=0)

# %%
#sns.barplot(x = 'year',y= 'robbery',data = berlin)
#plt.show()

# %%
# group the crimes committed by location
grouped_location = berlin.drop('year', axis=1).groupby('location').sum()
grouped_location
# Out:
#                                            robbery  street_robbery  injury  \
# location
# Adlershof                                      147              71    1138
# Albrechtstr.                                   290             138    2094
# Alexanderplatz                                1450             855   12330
# Allende-Viertel                                 15               5     346
# Alt-Hohenschönhausen Nord                       94              39    1252
# Alt-Hohenschönhausen Süd                       164              89    1842
# Alt-Lichtenberg                                321             186    3461
# Alt-Treptow                                    331             213    1231
# Altglienicke                                    66              39    1307
# Altstadt-Kietz                                  26              14     800
# Barstraße                                      118              68     988
# ...

# %% [markdown]
# ### Adding Longitudes and Latitudes to dataframe

# %%
berlin.head(5)
# Out:
#    year district           location  robbery  street_robbery  injury  \
# 0  2012    Mitte     Tiergarten Süd       70              46     586
# 1  2012    Mitte  Regierungsviertel       65              29     474
# 2  2012    Mitte     Alexanderplatz      242             136    1541
# 3  2012    Mitte  Brunnenstraße Süd       52              25     254
# 4  2012    Mitte        Moabit West      130              51     629
#
#    aggravated_assault  threat  theft  car  from_car  bike  burglary  fire  \
# 0                 194     118   2263   18       328   120        68    16
# 1                 123     142   3203   10       307   170        37    10
# 2                 454     304   8988   81       792   822       275    49
# 3                  60      66   1916   86       192   396       131    14
# 4                 185     199   2470   94       410   325       161    42
#
#    arson  damage  graffiti  drugs  dist.latitude  dist.longitude
# ...

# %%
berlin["dist.longitude"] = " "

# %%
berlin["dist.latitude"] = " "

# %%
berlin.head()
# Out:
#    year district   code           location  robbery  street_robbery  injury  \
# 0  2012    Mitte  10111     Tiergarten Süd       70              46     586
# 1  2012    Mitte  10112  Regierungsviertel       65              29     474
# 2  2012    Mitte  10113     Alexanderplatz      242             136    1541
# 3  2012    Mitte  10114  Brunnenstraße Süd       52              25     254
# 4  2012    Mitte  10221        Moabit West      130              51     629
#
#    aggravated_assault  threat  theft  ...  bike  burglary  fire  arson  \
# 0                 194     118   2263  ...   120        68    16      4
# 1                 123     142   3203  ...   170        37    10      4
# 2                 454     304   8988  ...   822       275    49     27
# 3                  60      66   1916  ...   396       131    14      5
# 4                 185     199   2470  ...   325       161    42     22
#
#    damage  graffiti  drugs  local  dist.latitude  dist.longitude
# ...

# %%
berlin['district'].unique()
# Out:
# array(['Mitte', 'Friedrichshain-Kreuzberg', 'Pankow',
#        'Charlottenburg-Wilmersdorf', 'Spandau', 'Steglitz-Zehlendorf',
#        'Tempelhof-Schöneberg', 'Neukölln', 'Treptow-Köpenick',
#        'Marzahn-Hellersdorf', 'Lichtenberg', 'Reinickendorf'],
#       dtype=object)

# %%
dist_map_lat = {
    "Mitte": 52.5373,
    "Friedrichshain-Kre2uzberg": 52.4996,
    "Pankow": 52.5929,
    "Charlottenburg-Wilmersdorf": 52.5053,
    "Spandau": 52.5352,
    "Steglitz-Zehlendorf": 52.4309,
    "Tempelhof-Schöneberg": 52.4722,
    "Neukölln": 52.4408,
    "Treptow-Köpenick": 52.4204,
    "Marzahn-Hellersdorf": 52.5229,
    "Lichtenberg": 52.5229,
    "Reinickendorf": 52.579
}

berlin["dist.latitude"] = berlin["district"].map(dist_map_lat)

# %%
dist_map_long = {
    "Mitte": 13.3603,
    "Friedrichshain-Kre2uzberg": 13.4314,
    "Pankow": 13.4317,
    "Charlottenburg-Wilmersdorf": 13.2600,
    "Spandau": 13.2003,
    "Steglitz-Zehlendorf": 13.1927,
    "Tempelhof-Schöneberg": 13.3703,
    "Neukölln": 13.4445,
    "Treptow-Köpenick": 13.6200,
    "Marzahn-Hellersdorf": 13.5766,
    "Lichtenberg": 13.4999,
    "Reinickendorf": 13.2805
}

berlin["dist.longitude"] = berlin["district"].map(dist_map_long)

# %%
berlin["location"].unique()
# Out:
# array(['Tiergarten Süd', 'Regierungsviertel', 'Alexanderplatz',
#        'Brunnenstraße Süd', 'Moabit West', 'Moabit Ost', 'Osloer Straße',
#        'Brunnenstraße Nord', 'Parkviertel', 'Wedding Zentrum',
#        'Bezirk (Mi), nicht zuzuordnen', 'Südliche Friedrichstadt',
#        'Tempelhofer Vorstadt', 'nördliche Luisenstadt',
#        'südliche Luisenstadt', 'Karl-Marx-Allee-Nord',
#        'Karl-Marx-Allee-Süd', 'Frankfurter Allee Nord',
#        'Frankfurter Allee Süd FK', 'Bezirk (Fh-Kb), nicht zuzuordnen',
#        'Buch', 'Blankenfelde/Niederschönhausen', 'Buchholz', 'Karow',
#        'Blankenburg/Heinersdorf/Märchenland',
#        'Schönholz/Wilhelmsruh/Rosenthal', 'Pankow Zentrum', 'Pankow Süd',
#        'Weißensee', 'Weißensee Ost', 'Prenzlauer Berg Nordwest',
#        'Prenzlauer Berg Nord', 'Helmholtzplatz', 'Prenzlauer Berg Ost',
#        'Prenzlauer Berg Südwest', 'Prenzlauer Berg Süd',
#        'Bezirk (Pk), nicht zuzuordnen', 'Charlottenburg-Nord',
# ...

# %%
berlin["loc.latitude"] = " "

loc_map_lat = {
    'Tiergarten Süd': 52.5027778,
    'Regierungsviertel': 52.5167,
    'Alexanderplatz': 52.521944,
    'Brunnenstraße Süd': 52.5257,
    'Moabit West': 52.525764,
    'Moabit Ost': 52.5317,
    'Osloer Straße': 52.545172,
    'Brunnenstraße Nord': 52.525664,
    'Parkviertel': 52.498333,
    'Wedding Zentrum': 52.5414,
    'Bezirk (Mi), nicht zuzuordnen': 52.518611,
    'Südliche Friedrichstadt': 52.506903,
    'Tempelhofer Vorstadt': 52.4822,
    'nördliche Luisenstadt': 52.517700,
    'südliche Luisenstadt': 52.498396,
    'Karl-Marx-Allee-Nord': 52.512831,
    'Karl-Marx-Allee-Süd': 52.514048,
    'Frankfurter Allee Nord': 52.511546,
    'Frankfurter Allee Süd FK': 52.515564,
    'Bezirk (Fh-Kb), nicht zuzuordnen': "nan",
    'Buch': 52.518611,
    'Blankenfelde/Niederschönhausen': 52.4008,
    'Buchholz': 52.4056413,
    'Karow': 52.506972,
    'Blankenburg/Heinersdorf/Märchenland': 52.561251,
    'Schönholz/Wilhelmsruh/Rosenthal': 52.5441667,
    'Pankow Zentrum': 52.5775,
    'Pankow Süd': 52.403453,
    'Weißensee': 52.4646,
    'Weißensee Ost': 52.452778,
    'Prenzlauer Berg Nordwest': 52.540720,
    'Prenzlauer Berg Nord': 52.542211,
    'Helmholtzplatz': 52.510,
    'Prenzlauer Berg Ost': 52.528714,
    'Prenzlauer Berg Südwest': 52.535132,
    'Prenzlauer Berg Süd': 52.5357,
    'Bezirk (Pk), nicht zuzuordnen': 13.36768,
    'Charlottenburg-Nord': 52.5411975,
    'Heerstraße': 52.5155,
    'Westend': 52.5069,
    'Schloss Charlottenburg': 52.516275,
    'Mierendorffplatz': 52.494874,
    'Otto-Suhr-Allee': 52.502778,
    'Neue Kantstraße': 52.502724,
    'Kantstraße': 52.502778,
    'Kurfürstendamm': 52.5019,
    'Halensee': 52.497809,
    'Grunewald': 52.406822,
    'Schmargendorf': 52,
    'Wiesbadener Straße': 52.542215,
    'Düsseldorfer Straße': 52.518611,
    'Barstraße': 52.516464,
    'Volkspark Wilmersdorf': 52.457134,
    'Forst Grunewald': 52.4667,
    'Bezirk (Ch-Wi), nicht zuzuordnen': 525.243700,
    'Hakenfelde': 52.55877,
    'Falkenhagener Feld': 52.518611,
    'Spandau Mitte': 52.541211,
    'Brunsbütteler Damm': 525.008,
    'Heerstraße Nord': 52.52007,
    'Wilhelmstadt': 52.473407,
    'Haselhorst': 52.506912,
    'Siemensstadt': 52.48142,
    'Gatow/Kladow': 52.420126,
    'Bezirk (Sp), nicht zuzuordnen': 525.3214,
    'Schloßstr.': 525.200066,
    'Albrechtstr.': 52.519047,
    'Lankwitz': 52.430833,
    'Ostpreußendamm': 13.2877,
    'Teltower Damm': 52.408611,
    'Drakestr.': 525.167,
    'Zehlendorf Südwest': 52.270080,
    'Zehlendorf Nord': 52.397611,
    'Bezirk (St-Zd), nicht zuzuordnen': 525.167,
    'Schöneberg-Nord': 52.474722,
    'Schöneberg-Süd': 52.4764,
    'Friedenau': 52.5,
    'Tempelhof': 52.473612,
    'Mariendorf': 52.45534,
    'Marienfelde': 52.408542,
    'Lichtenrade': 52.3875,
    'Bezirk (Th-Sb), nicht zuzuordnen': "nan",
    'Schillerpromenade': 52.4875,
    'Neuköllner Mitte/Zentrum': 52.4722,
    'Reuterstraße': 52.516433,
    'Rixdorf': 52.46665,
    'Köllnische Heide': 52.472812,
    'Britz': 52.5167,
    'Buckow': 52.4333,
    'Gropiusstadt': 52.435706,
    'Buckow Nord': 52.5667,
    'Rudow': 52.408333,
    'Bezirk (Nk), nicht zuzuordnen': 52.5,
    'Alt-Treptow': 52.4822,
    'Plänterwald': 524.719,
    'Baumschulenweg': 52.432222,
    'Johannisthal': 52.432222,
    'Oberschöneweide': 52.445891,
    'Niederschöneweide': 52.458333,
    'Adlershof': 52.404118,
    'Köllnische Vorstadt/Spindlersfeld': 52.479430,
    'Altglienicke': 52.39648,
    'Bohnsdorf': 52.4719,
    'Grünau': 52.4046,
    'Schmöckwitz/Karolinenhof/Rauchfangswerder': 52.3087,
    'Köpenick-Süd': 52.4322,
    'Allende-Viertel': 52.482972,
    'Altstadt-Kietz': 52.496475,
    'Müggelheim': 52.4822,
    'Friedrichshagen': 52.440138,
    'Rahnsdorf/Hessenwinkel': 52.4719,
    'Dammvorstadt': 52.468468,
    'Köpenick-Nord': 52.468468,
    'Bezirk (Tp-Kp), nicht zuzuordnen': "nan",
    'Marzahn-Nord': 52.5469,
    'Marzahn-Mitte': 52.538580,
    'Marzahn-Süd': 52.547222,
    'Hellersdorf-Nord': 52.5200066,
    'Hellersdorf-Ost': 52.471119,
    'Hellersdorf-Süd': 52.451119,
    'Biesdorf': 52.5069,
    'Kaulsdorf': 52.45,
    'Mahlsdorf': 13.57722,
    'Bezirk (Mz-Hd), nicht zuzuordnen': 52.520007,
    'Malchow': 52.5519,
    'Wartenberg': 52.5090,
    'Falkenberg': 52.4667,
    'Neu-Hohenschönhausen Nord': 52.602222,
    'Neu-Hohenschönhausen Süd': 52.533096,
    'Alt-Hohenschönhausen Nord': 52.53,
    'Alt-Hohenschönhausen Süd': 52.531944,
    'Fennpfuhl': 52.52778,
    'Alt-Lichtenberg': 52.529942,
    'Frankfurter Allee Süd': 52.4981,
    'Neu Lichtenberg': 52.565269,
    'Friedrichsfelde Nord': 52.35,
    'Friedrichsfelde Süd': 52.3333,
    'Rummelsburger Bucht': 52.48092,
    'Karlshorst': 52.333,
    'Bezirk (Lb), nicht zuzuordnen': 52.52437,
    'Ost 1 - Reginhardstr.': 52.5167,
    'Ost 2 - Alt-Reinickendorf': 52.584722,
    'West 1 - Tegel-Süd/Flughafensee': 52.54522,
    'West 4 - Auguste-Viktoria-Allee': 52.50274,
    'West 5 - Tegel/Tegeler Forst': 52.55,
    'West 2 - Heiligensee/Konradshöhe': 52.598746,
    'Nord 1 - Frohnau/Hermsdorf': 52.570065,
    'Nord 2 - Waidmannslust/Wittenau/Lübars': 52.602778,
    'MV 1 - Märkisches Viertel': 52.555,
    'MV 2 - Rollbergsiedlung': 52.479942,
    'West 3 - Borsigwalde/Freie Scholle': 52.529964,
    'Bezirk (Rd), nicht zuzuordnen': 52.52437
}

berlin["loc.latitude"] = berlin["location"].map(loc_map_lat)

# %%
berlin["loc.longitude"] = " "

loc_map_long = {
    'Tiergarten Süd': 13.2888889,
    'Regierungsviertel': 13.3833,
    'Alexanderplatz': 13.412778,
    'Brunnenstraße Süd':  13.4153,
    'Moabit West': 13.352475,
    'Moabit Ost': 13.3435,
    'Osloer Straße': 13.357397,
    'Brunnenstraße Nord': 13.413671,
    'Parkviertel': 13.349722,
    'Wedding Zentrum':  13.3289,
    'Bezirk (Mi), nicht zuzuordnen': 13.368333,
    'Südliche Friedrichstadt': 13.360297,
    'Tempelhofer Vorstadt': 13.4289,
    'nördliche Luisenstadt': 13.404954,
    'südliche Luisenstadt': 13.415565,
    'Karl-Marx-Allee-Nord': 13.468155,
    'Karl-Marx-Allee-Süd': 13.457707,
    'Frankfurter Allee Nord': 13.458067,
    'Frankfurter Allee Süd FK': 13.452273,
    'Bezirk (Fh-Kb), nicht zuzuordnen': "nan",
    'Buch': 13.408333,
    'Blankenfelde/Niederschönhausen': 13.2914,
    'Buchholz': 13.2666072,
    'Karow': 13.329415,
    'Blankenburg/Heinersdorf/Märchenland': 13.479497,
    'Schönholz/Wilhelmsruh/Rosenthal': 13.4208333,
    'Pankow Zentrum': 13.404954 ,
    'Pankow Süd': 13.403522,
    'Weißensee':  13.4153,
    'Weißensee Ost': 13.523889,
    'Prenzlauer Berg Nordwest': 13.413060,
    'Prenzlauer Berg Nord': 13.412744,
    'Helmholtzplatz': 13.3238,
    'Prenzlauer Berg Ost': 13.435622,
    'Prenzlauer Berg Südwest': 13.408749,
    'Prenzlauer Berg Süd': 13.4105,
    'Bezirk (Pk), nicht zuzuordnen': 13.36768,
    'Charlottenburg-Nord': 13.36768,
    'Heerstraße': 13.2926,
    'Westend': 13.3449,
    'Schloss Charlottenburg': 13.30867,
    'Mierendorffplatz': 13.401451,
    'Otto-Suhr-Allee': 13.289722,
    'Neue Kantstraße': 13.326435,
    'Kantstraße': 13.289722,
    'Kurfürstendamm': 13.3375,
    'Halensee': 13.281011,
    'Grunewald': 13.238781,
    'Schmargendorf':13.272438,
    'Wiesbadener Straße': 13.394324,
    'Düsseldorfer Straße': 13.399972,
    'Barstraße': 13.368404,
    'Volkspark Wilmersdorf': 13.286271,
    'Forst Grunewald': 13.21,
    'Bezirk (Ch-Wi), nicht zuzuordnen': 134.105300,
    'Hakenfelde': 13.24,
    'Falkenhagener Feld': 13.208333,
    'Spandau Mitte': 13.193592,
    'Brunsbütteler Damm': 13.3619,
    'Heerstraße Nord': 13.39151,
    'Wilhelmstadt': 13.235676,
    'Haselhorst': 13.289467,
    'Siemensstadt': 13.37092,
    'Gatow/Kladow': 13.19518,
    'Bezirk (Sp), nicht zuzuordnen': 13.35861,
    'Schloßstr.': 13.404954,
    'Albrechtstr.': 13.398756,
    'Lankwitz': 13.405 ,
    'Ostpreußendamm': 13.2877,
    'Teltower Damm': 13.185278,
    'Drakestr.': 13.3833,
    'Zehlendorf Südwest': 13.255150,
    'Zehlendorf Nord': 13.279972,
    'Bezirk (St-Zd), nicht zuzuordnen': 13.3833,
    'Schöneberg-Nord': 13.342222,
    'Schöneberg-Süd': 13.3486,
    'Friedenau': 13.3,
    'Tempelhof': 13.392375,
    'Mariendorf': 13.46575,
    'Marienfelde': 13.519397,
    'Lichtenrade': 13.4643,
    'Bezirk (Th-Sb), nicht zuzuordnen': 13.4,
    'Schillerpromenade': 13.39583,
    'Neuköllner Mitte/Zentrum':  13.4667,
    'Reuterstraße': 13.387221,
    'Rixdorf': 13.44571,
    'Köllnische Heide': 13.377767,
    'Britz': 13.4050,
    'Buckow': 13.4667,
    'Gropiusstadt': 13.537733,
    'Buckow Nord': 13.5667,
    'Rudow': 13.456944,
    'Bezirk (Nk), nicht zuzuordnen': 13.4,
    'Alt-Treptow': 13.43836,
    'Plänterwald': 13.4065,
    'Baumschulenweg': 13.531953,
    'Johannisthal': 13.545278,
    'Oberschöneweide': 13.503486,
    'Niederschöneweide': 13.5,
    'Adlershof': 13.547669,
    'Köllnische Vorstadt/Spindlersfeld': 13.417750,
    'Altglienicke': 13.58499,
    'Bohnsdorf': 13.5085,
    'Grünau':13.5928,
    'Schmöckwitz/Karolinenhof/Rauchfangswerder': 13.6311,
    'Köpenick-Süd': 13.8772,
    'Allende-Viertel': 13.404954,
    'Altstadt-Kietz': 13.545278,
    'Müggelheim':  13.5756,
    'Friedrichshagen': 13.580674,
    'Rahnsdorf/Hessenwinkel': 13.5767,
    'Dammvorstadt': 13.357081,
    'Köpenick-Nord': 13.569842,
    'Bezirk (Tp-Kp), nicht zuzuordnen': "nan",
    'Marzahn-Nord': 13.5995,
    'Marzahn-Mitte': 13.567410,
    'Marzahn-Süd': 13.579444,
    'Hellersdorf-Nord': 13.6186045,
    'Hellersdorf-Ost': 13.562153,
    'Hellersdorf-Süd': 13.650893,
    'Biesdorf':  13.5092,
    'Kaulsdorf':  13.53,
    'Mahlsdorf': 13.57722,
    'Bezirk (Mz-Hd), nicht zuzuordnen': 13.404954,
    'Malchow':13.827 ,
    'Wartenberg': 13.330,
    'Falkenberg':13.1000 ,
    'Neu-Hohenschönhausen Nord': 13.519444,
    'Neu-Hohenschönhausen Süd': 13.502756,
    'Alt-Hohenschönhausen Nord':  13.48,
    'Alt-Hohenschönhausen Süd': 13.481120,
    'Fennpfuhl': 13.51111,
    'Alt-Lichtenberg': 13.529721,
    'Frankfurter Allee Süd': 13.3983,
    'Neu Lichtenberg': 13.568939,
    'Friedrichsfelde Nord': 13.5167,
    'Friedrichsfelde Süd': 13.5167,
    'Rummelsburger Bucht': 13.43763,
    'Karlshorst': 13.6333,
    'Bezirk (Lb), nicht zuzuordnen': 13.41053,
    'Ost 1 - Reginhardstr.': 13.3833,
    'Ost 2 - Alt-Reinickendorf': 13.320833,
    'West 1 - Tegel-Süd/Flughafensee': 13.27988,
    'West 4 - Auguste-Viktoria-Allee': 13.2857,
    'West 5 - Tegel/Tegeler Forst': 13.283,
    'West 2 - Heiligensee/Konradshöhe': 13.297437,
    'Nord 1 - Frohnau/Hermsdorf': 13.355126,
    'Nord 2 - Waidmannslust/Wittenau/Lübars': 13.329722,
    'MV 1 - Märkisches Viertel': 13.35,
    'MV 2 - Rollbergsiedlung': 13.430176,
    'West 3 - Borsigwalde/Freie Scholle': 13.528938,
    'Bezirk (Rd), nicht zuzuordnen':  13.41053,
}

berlin["loc.longitude"] = berlin["location"].map(loc_map_long)

# %%
berlin.head(5)
# Out:
#    year district           location  robbery  street_robbery  injury  \
# 0  2012    Mitte     Tiergarten Süd       70              46     586
# 1  2012    Mitte  Regierungsviertel       65              29     474
# 2  2012    Mitte     Alexanderplatz      242             136    1541
# 3  2012    Mitte  Brunnenstraße Süd       52              25     254
# 4  2012    Mitte        Moabit West      130              51     629
#
#    aggravated_assault  threat  theft  car  ...  burglary  fire  arson  damage  \
# 0                 194     118   2263   18  ...        68    16      4     273
# 1                 123     142   3203   10  ...        37    10      4     380
# 2                 454     304   8988   81  ...       275    49     27    1538
# 3                  60      66   1916   86  ...       131    14      5     428
# 4                 185     199   2470   94  ...       161    42     22     516
#
#    graffiti  drugs  dist.latitude  dist.longitude  loc.latitude  loc.longitude
# ...

# %%
berlin = berlin.drop('loc.latitude',axis=1)
berlin = berlin.drop('loc.longitude',axis=1)

# %%
#df1 = berlin.to_csv(index=0)

berlin.to_csv('/Users/festusoladipo/Desktop/GitHub/Final_Project/berlin.csv',index=0)

# %%
berlin.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/v6/6m2bpdm12rn2zbd3w9c2c7q00000gn/T/ipykernel_22102/1886538346.py in <module>
# ----> 1 berlin.head(10)
#
# NameError: name 'berlin' is not defined

# %% [markdown]
# ### What Part of Berlin is most dangerous

# %% [markdown]
# #### Highest amount of crime per crimes

# %%
num_df = berlin.select_dtypes("number").drop("year", axis=1)

# %%
num_df
# Out:
#       robbery  street_robbery  injury  aggravated_assault  threat  theft  car  \
# 0          70              46     586                 194     118   2263   18
# 1          65              29     474                 123     142   3203   10
# 2         242             136    1541                 454     304   8988   81
# 3          52              25     254                  60      66   1916   86
# 4         130              51     629                 185     199   2470   94
# 5          89              45     549                 147     204   2290   63
# 6         120              46     785                 223     267   3666   52
# 7         145              71     675                 192     191   2928   76
# 8         109              48     783                 211     318   2879   77
# 9         216             104    1210                 426     384   3396   57
# 10         15               9     435                 147      49   2487    6
# ...

# %%
# calculate the sum of each nominal column
#total_sum = 0
#for col in num_df.columns:
 #   print(col, berlin[col].sum())

# %%
#total_sum

# %%
# identify nominal columns with less than 10000 unique values
nominal_cols = []
for col in berlin.columns:
    if berlin[col].nunique() <= 10000 and col not in ['district', 'location','year','code']: # excluding categorical columns
        nominal_cols.append(col)

# calculate the sum of each nominal column
column_sums = {}
for col in nominal_cols:
    column_sum = berlin[col].sum()
    column_sums[col] = column_sum

# print the results
print(column_sums)
# Out:
# {'robbery': 41080, 'street_robbery': 22493, 'injury': 331601, 'aggravated_assault': 82500, 'threat': 111100, 'theft': 1790769, 'car': 51007, 'from_car': 258330, 'bike': 237248, 'burglary': 83387, 'fire': 19189, 'arson': 7538, 'damage': 337899, 'graffiti': 75461, 'drugs': 117431}

# %% [markdown]
# #### Total number of crimes across all crimes

# %%
numerical_cols = berlin.select_dtypes(include=['number']).drop('year', axis=1)
sum_total = numerical_cols.sum().sum()
print(sum_total)

#def sum_numerical_cols(df, exclude_col):
 #   numerical_cols = df.select_dtypes(include=['number']).drop(exclude_col, axis=1)
  #  sum_total = numerical_cols.sum().sum()
   # return sum_total
#sum_total
# Out:
# 3567033

# %% [markdown]
# #### Total number of crimes per district

# %%
berlin.groupby("location").sum()
# Out:
#                                             year  robbery  street_robbery  \
# location
# Adlershof                                  16124      147              71
# Albrechtstr.                               16124      290             138
# Alexanderplatz                             16124     1450             855
# Allende-Viertel                            16124       15               5
# Alt-Hohenschönhausen Nord                  16124       94              39
# Alt-Hohenschönhausen Süd                   16124      164              89
# Alt-Lichtenberg                            16124      321             186
# Alt-Treptow                                16124      331             213
# Altglienicke                               16124       66              39
# Altstadt-Kietz                             16124       26              14
# Barstraße                                  16124      118              68
# ...

# %%
berlin[berlin["district"] == "Mitte"].sum()
# Out:
# year                                                             177364
# district              MitteMitteMitteMitteMitteMitteMitteMitteMitteM...
# location              Tiergarten SüdRegierungsviertelAlexanderplatzB...
# robbery                                                            7582
# street_robbery                                                     4225
# injury                                                            59628
# aggravated_assault                                                15730
# threat                                                            17130
# theft                                                            328450
# car                                                                4186
# from_car                                                          34665
# bike                                                              33574
# burglary                                                           9915
# ...

# %%
crimes_district = berlin.groupby('district')[['robbery', 'theft', 'street_robbery', 'injury', 'aggravated_assault','threat', 'car','from_car','bike','burglary','fire','arson','damage','graffiti','drugs']].sum()
crimes_district['total_crimes'] = crimes_district['robbery'] + crimes_district['theft'] + crimes_district['street_robbery'] + crimes_district['injury']+ crimes_district['aggravated_assault']+ crimes_district['threat']+ crimes_district['car']+ crimes_district['from_car']+ crimes_district['bike']+ crimes_district['burglary']+ crimes_district['fire']+ crimes_district['arson']+ crimes_district['damage']+ crimes_district['graffiti']+ crimes_district['drugs']
grouped_crimes_district.sum()
# Out:
# 1854342

# %% [markdown]
# #### Ratio of crime per district

# %%
district_percentages = round((grouped_crimes_district / sum_total) * 100)
print(district_percentages)
# Out:
# district
# Charlottenburg-Wilmersdorf     6.0
# Friedrichshain-Kreuzberg       6.0
# Lichtenberg                    3.0
# Marzahn-Hellersdorf            2.0
# Mitte                         10.0
# Neukölln                       5.0
# Pankow                         5.0
# Reinickendorf                  3.0
# Spandau                        3.0
# Steglitz-Zehlendorf            3.0
# Tempelhof-Schöneberg           4.0
# Treptow-Köpenick               3.0
# Name: total_crimes, dtype: float64

# %% [markdown]
# ### sum of crimes

# %%
berlin.columns
# Out:
# Index(['Year', 'District', 'Code', 'Location', 'Robbery', 'Street_robbery',
#        'Injury', 'Aggravated_assault', 'Threat', 'Theft', 'Car', 'From_car',
#        'Bike', 'Burglary', 'Fire', 'Arson', 'Damage', 'Graffiti', 'Drugs',
#        'Local'],
#       dtype='object')

# %%
sum_value = np.sum(berlin['Robbery'])
print(sum_value)
# Out:
# 41080
